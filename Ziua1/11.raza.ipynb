# %%
raza = int(input("Valoarea razei: "))
arie_cerc = 3.1415 * raza**2
print(arie_cerc)
# Out:
# 314.15000000000003

# %% [markdown]
# # In Python nu exista constante. Constante sunt conventii

# %%
PI = 3.141562

# %% [markdown]
# # Exista o conventie -> litere mari avem constante

# %%
PI = 23
