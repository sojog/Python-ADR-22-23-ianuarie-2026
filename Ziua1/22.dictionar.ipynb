# %%
a = [123, 342, 432, 432, 11]
print(len(a))
# Out:
# 5

# %%
a = ["albastru", "rosu", "verde", "negru"]
print(a[0])
# Out:
# albastru

# %%
d = { "cer": "albastru", "sange": "rosu", "iarba": "verde", "cafea": "negru"}
print(d["cer"])
# Out:
# albastru

# %%
d = { "cer": "albastru", "sange": "rosu", "iarba": "verde", "cafea": "negru"}
for i in d:
    print("i=", i)
# Out:
# i= cer
# i= sange
# i= iarba
# i= cafea

# %%
d = { "cer": "albastru", "sange": "rosu", "iarba": "verde", "cafea": "negru"}
for i in d:
    print("valoarea=", d[i])
# Out:
# valoarea= albastru
# valoarea= rosu
# valoarea= verde
# valoarea= negru

# %%
d = { "cer": "albastru", "sange": "rosu", "iarba": "verde", "cafea": "negru"}
d.keys()
# Out:
# dict_keys(['cer', 'sange', 'iarba', 'cafea'])

# %%
d = { "cer": "albastru", "sange": "rosu", "iarba": "verde", "cafea": "negru"}
d.values()
# Out:
# dict_values(['albastru', 'rosu', 'verde', 'negru'])

# %%
d = { "cer": "albastru", "sange": "rosu", "iarba": "verde", "cafea": "negru"}
len(d)
# Out:
# 4

# %%
d = { "cer": "albastru", "sange": "rosu", "iarba": "verde", "cafea": "negru"}
d["sange"]
# Out:
# 'rosu'

# %% [markdown]
# # Dictionarul este o colectie mutabila

# %%
d = { "cer": "albastru", "sange": "rosu", "iarba": "verde", "cafea": "negru"}
d["cer"] = "gri"
print(d)
# Out:
# {'cer': 'gri', 'sange': 'rosu', 'iarba': 'verde', 'cafea': 'negru'}

# %%
d["foaie"] = "alb"
print(d)
# Out:
# {'cer': 'gri', 'sange': 'rosu', 'iarba': 'verde', 'cafea': 'negru', 'foaie': 'alb'}

# %%
d = { "cer": "albastru", "cer":"gri" , "sange": "rosu", "sange":"albastru", "iarba": "verde", "cafea": "negru"}
d
# Out:
# {'cer': 'gri', 'sange': 'albastru', 'iarba': 'verde', 'cafea': 'negru'}
