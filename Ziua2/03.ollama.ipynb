# %% [markdown]
# # pip install requests

# %%
import requests

# %%
response = requests.get("http://localhost:11434/api/version")

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"version":"0.14.3"}'

# %%
payload = {
    "model" : "qwen2.5-coder:14b",
    "prompt": "Explica-mi cum functioneaza libraria Requests in Python",
    "stream" : False
}

# %%
response = requests.post("http://localhost:11434/api/generate",json=payload)

# %%
response.content
# Out:
# b'{"model":"qwen2.5-coder:14b","created_at":"2026-01-23T07:34:54.318267Z","response":"Libraria `requests` \xc3\xaen Python este o bibliotec\xc4\x83 popular\xc4\x83 pentru efectuarea de cereri HTTP (GET, POST, PUT, DELETE, etc.) c\xc4\x83tre serverele web. Ea simplific\xc4\x83 procesul de comunicare cu API-uri \xc8\x99i alte surse web. Iat\xc4\x83 cum func\xc8\x9bioneaz\xc4\x83:\\n\\n1. **Instalare**: Pentru a folosi libraria `requests`, trebuie mai \xc3\xaent\xc3\xa2i instalat\xc4\x83. Aceasta poate fi f\xc4\x83cut\xc4\x83 utiliz\xc3\xa2nd pip:\\n   ```bash\\n   pip install requests\\n   ```\\n\\n2. **Solicita\xc8\x9bi cereri HTTP**: Libraria permite efectuarea de cereri HTTP u\xc8\x99or \xc8\x99i rapid.\\n\\n   - **GET Request**:\\n     ```python\\n     import requests\\n\\n     response = requests.get(\'https://api.example.com/data\')\\n     print(response.status_code)\\n     print(response.text)\\n     ```\\n\\n   - **POST Request**:\\n     ```python\\n     import requests\\n\\n     data = {\'key\': \'value\'}\\n     response = requests.post(\'https://api.example.com/submit\', json=data)\\n     print(response.status_code)\\n     print(response.json())\\n     ```\\n\\n3. **Managementul de erori**: Poate gestiona diferite tipuri de erori, cum ar fi problemele de re\xc8\x9bea sau r\xc4\x83spunsurile HTTP nea\xc8\x99teptate.\\n\\n   ```python\\n   try:\\n       response = requests.get(\'https://api.example.com/data\')\\n       response.raise_for_status()  # Ridic\xc4\x83 o eroare pentru statusuri HTTP \\u003e= 400\\n   except requests.exceptions.RequestException as e:\\n       print(f\\"Error: {e}\\")\\n   ```\\n\\n4. **Cookies \xc8\x99i autentificare**: Poate gestiona cookie-urile automat \xc8\x99i poate fi folosit\xc4\x83 pentru a face cereri autentificate.\\n\\n   - **Cookies**:\\n     ```python\\n     response = requests.get(\'https://api.example.com/data\')\\n     cookies = response.cookies\\n     ```\\n\\n   - **Autentificare**:\\n     ```python\\n     from requests.auth import HTTPBasicAuth\\n\\n     response = requests.get(\'https://api.example.com/secure\', auth=HTTPBasicAuth(\'user\', \'pass\'))\\n     ```\\n\\n5. **Timeout**: Poate seta timeout-uri pentru a preveni blocarea programului \xc3\xaen cazul r\xc4\x83spunsurilor serverului prea lente.\\n\\n   ```python\\n   try:\\n       response = requests.get(\'https://api.example.com/data\', timeout=10)\\n   except requests.exceptions.Timeout as e:\\n       print(f\\"Timeout Error: {e}\\")\\n   ```\\n\\n6. **Sesiuni**: Poate utiliza sesiuni pentru a men\xc8\x9bine persisten\xc8\x9ba cererilor, cum ar fi cookie-urile \xc8\x99i alte informa\xc8\x9bii de stare.\\n\\n   ```python\\n   session = requests.Session()\\n   response1 = session.get(\'https://api.example.com/data\')\\n   response2 = session.post(\'https://api.example.com/submit\', json={\'key\': \'value\'})\\n   ```\\n\\n7. **Proxy**: Poate configura cererile prin intermediu unui proxy.\\n\\n   ```python\\n   proxies = {\\n       \'http\': \'http://10.10.1.10:3128\',\\n       \'https\': \'http://10.10.1.10:1080\',\\n   }\\n\\n   response = requests.get(\'https://api.example.com/data\', proxies=proxies)\\n   ```\\n\\nLibraria `requests` este extrem de u\xc8\x99or de folosit \xc8\x99i este \xc3\xaencredibil de popular pentru lucrul cu API-uri \xc8\x99i alte interac\xc8\x9biuni web din Python. Ea abstractizeaz\xc4\x83 multe detalii ale comunic\xc4\x83rii HTTP, l\xc4\x83s\xc3\xa2nd dezvoltatorului s\xc4\x83 se concentreze pe logic\xc4\x83 specific\xc4\x83 aplica\xc8\x9biei.","done":true,"done_reason":"stop","context":[151644,8948,198,2610,525,1207,16948,11,3465,553,54364,14817,13,1446,525,264,10950,17847,13,151645,198,151644,872,198,8033,15317,1448,72,12177,729,68,12707,60359,10432,50882,304,13027,151645,198,151644,77091,198,9194,81,10432,1565,36242,63,18531,13027,10351,297,43515,88162,6705,5411,6705,26220,42946,84,4798,409,10152,30703,10130,320,3806,11,12869,11,34380,11,17197,11,4992,6138,39257,10157,3538,10068,3482,13 ...

# %%
print(response.json()['response'])
# Out:
# Libraria `requests` în Python este o bibliotecă populară pentru efectuarea de cereri HTTP (GET, POST, PUT, DELETE, etc.) către serverele web. Ea simplifică procesul de comunicare cu API-uri și alte surse web. Iată cum funcționează:
#
# 1. **Instalare**: Pentru a folosi libraria `requests`, trebuie mai întâi instalată. Aceasta poate fi făcută utilizând pip:
#    ```bash
#    pip install requests
#    ```
#
# 2. **Solicitați cereri HTTP**: Libraria permite efectuarea de cereri HTTP ușor și rapid.
#
#    - **GET Request**:
#      ```python
#      import requests
#
#      response = requests.get('https://api.example.com/data')
#      print(response.status_code)
#      print(response.text)
#      ```
#
#    - **POST Request**:
#      ```python
#      import requests
#
#      data = {'key': 'value'}
#      response = requests.post('https://api.example.com/submit', json=data)
#      print(response.status_code)
#      print(response.json())
#      ```
#
# 3. **Managementul de erori**: Poate gestiona diferite tipuri de erori, cum ar fi problemele de rețea sau răspunsurile HTTP neașteptate.
#
#    ```python
#    try:
#        response = requests.get('https://api.example.com/data')
#        response.raise_for_status()  # Ridică o eroare pentru statusuri HTTP >= 400
#    except requests.exceptions.RequestException as e:
#        print(f"Error: {e}")
#    ```
#
# 4. **Cookies și autentificare**: Poate gestiona cookie-urile automat și poate fi folosită pentru a face cereri autentificate.
#
#    - **Cookies**:
#      ```python
#      response = requests.get('https://api.example.com/data')
#      cookies = response.cookies
#      ```
#
#    - **Autentificare**:
#      ```python
#      from requests.auth import HTTPBasicAuth
#
#      response = requests.get('https://api.example.com/secure', auth=HTTPBasicAuth('user', 'pass'))
#      ```
#
# 5. **Timeout**: Poate seta timeout-uri pentru a preveni blocarea programului în cazul răspunsurilor serverului prea lente.
#
#    ```python
#    try:
#        response = requests.get('https://api.example.com/data', timeout=10)
#    except requests.exceptions.Timeout as e:
#        print(f"Timeout Error: {e}")
#    ```
#
# 6. **Sesiuni**: Poate utiliza sesiuni pentru a menține persistența cererilor, cum ar fi cookie-urile și alte informații de stare.
#
#    ```python
#    session = requests.Session()
#    response1 = session.get('https://api.example.com/data')
#    response2 = session.post('https://api.example.com/submit', json={'key': 'value'})
#    ```
#
# 7. **Proxy**: Poate configura cererile prin intermediu unui proxy.
#
#    ```python
#    proxies = {
#        'http': 'http://10.10.1.10:3128',
#        'https': 'http://10.10.1.10:1080',
#    }
#
#    response = requests.get('https://api.example.com/data', proxies=proxies)
#    ```
#
# Libraria `requests` este extrem de ușor de folosit și este încredibil de popular pentru lucrul cu API-uri și alte interacțiuni web din Python. Ea abstractizează multe detalii ale comunicării HTTP, lăsând dezvoltatorului să se concentreze pe logică specifică aplicației.
