# %% [markdown]
# # Operatie de atribuire

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# # Operatie de comparatie

# %%
x == 10
# Out:
# True

# %%
x > 10
# Out:
# False

# %%
x >= 10
# Out:
# True

# %%
x != 10 # Diferit
# Out:
# False

# %%
x != 1321 # Diferit
# Out:
# True

# %%
x = input("Introdu prima valoare")
y = input("Introdu a doua valoare")

print("Este aceeasi valoare?", x == y)
# Out:
# Este aceeasi valoare? True
