# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# # Python este case sensitive

# %%
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(X)
#
# NameError: name 'X' is not defined

# %% [markdown]
# # Nu pot avea spatiu in nume de variabila

# %%
o_variabila = 10
print(o_variabila)
# Out:
# 10

# %% [markdown]
# # Cuvinte cheie nu pot fi nume de variabila

# %%
if = 10
# Out:
#   Cell In[5], line 1
#     if = 10
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Numele nu pot incepe cu cifre

# %%
2var = 23
# Out:
#   Cell In[6], line 1
#     2var = 23
#     ^
# SyntaxError: invalid decimal literal

# %%
var2 = 23
