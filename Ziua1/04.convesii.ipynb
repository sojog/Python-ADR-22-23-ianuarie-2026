# %% [markdown]
# # Converie de la INT catre alte tipuri de date

# %%
# INT
x = 23
print(x, type(x))
# Out:
# 23 <class 'int'>

# %%
x = float(23)
print(x, type(x))
# Out:
# 23.0 <class 'float'>

# %%
x = 308210
x = str(x)
print(x, type(x))
# Out:
# 308210 <class 'str'>

# %%
x = 308210
x = bool(x)
print(x, type(x))
# Out:
# True <class 'bool'>

# %%
x = 0
x = bool(x)
print(x, type(x))
# Out:
# False <class 'bool'>

# %% [markdown]
# # Conversie de la Bool catre celalte tipuri de date

# %%
x = True
print(x, type(x))
# Out:
# True <class 'bool'>

# %%
x = True
x = int(x)
print(x, type(x))
# Out:
# 1 <class 'int'>

# %%
x = False
x = int(x)
print(x, type(x))
# Out:
# 0 <class 'int'>

# %%
x = True
x = float(x)
print(x, type(x))
# Out:
# 1.0 <class 'float'>

# %%
x = False
x = float(x)
print(x, type(x))
# Out:
# 0.0 <class 'float'>

# %%
x = True
x = str(x)
print(x, type(x))
# Out:
# True <class 'str'>

# %% [markdown]
# # Conversie de la Float catre alte tipuri

# %%
x = 23.3
print(x, type(x))
# Out:
# 23.3 <class 'float'>

# %%
x = 23.3
x = int(x)
print(x, type(x))
# Out:
# 23 <class 'int'>

# %%
x = 23.3
x = bool(x)
print(x, type(x))
# Out:
# True <class 'bool'>

# %%
x = 0.0
x = bool(x)
print(x, type(x))
# Out:
# False <class 'bool'>

# %%
x = -23.3
x = bool(x)
print(x, type(x))
# Out:
# True <class 'bool'>

# %%
x = -23.3
x = str(x)
print(x, type(x))
# Out:
# -23.3 <class 'str'>

# %% [markdown]
# # Conversie de la String catre celelate tipuri de date

# %%
x = "32"
x = int(x)
print(x, type(x))
# Out:
# 32 <class 'int'>

# %%
x = "dsad"
x = int(x)
print(x, type(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 x = "dsad"
# ----> 2 x = int(x)
#       3 print(x, type(x))
#
# ValueError: invalid literal for int() with base 10: 'dsad'

# %%
x = "32"
x = float(x)
print(x, type(x))
# Out:
# 32.0 <class 'float'>

# %%
x = "32.032"
x = float(x)
print(x, type(x))
# Out:
# 32.032 <class 'float'>

# %%
x = "32.032"
x = int(x)
print(x, type(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 x = "32.032"
# ----> 2 x = int(x)
#       3 print(x, type(x))
#
# ValueError: invalid literal for int() with base 10: '32.032'

# %%
x = "32.032"
x = bool(x)
print(x, type(x))
# Out:
# True <class 'bool'>

# %%
x = "?"
x = bool(x)
print(x, type(x))
# Out:
# True <class 'bool'>

# %%
x = ""
x = bool(x)
print(x, type(x))
# Out:
# False <class 'bool'>
