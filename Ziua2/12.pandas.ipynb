# %%
import pandas as pd # alias conventional
import numpy as np

# %%
print(pd.__doc__)
# Out:
# pandas - a powerful data analysis and manipulation library for Python
# ...
#
# **pandas** is a Python package providing fast, flexible, and expressive data
# structures designed to make working with "relational" or "labeled" data both
# easy and intuitive. It aims to be the fundamental high-level building block for
# doing practical, **real world** data analysis in Python. Additionally, it has
# the broader goal of becoming **the most powerful and flexible open source data
# analysis / manipulation tool available in any language**. It is already well on
# its way toward this goal.
#
# Main Features
# -------------
# Here are just a few of the things that pandas does well:
#
#   - Easy handling of missing data in floating point as well as non-floating
#     point data.
#   - Size mutability: columns can be inserted and deleted from DataFrame and
#     higher dimensional objects
#   - Automatic and explicit data alignment: objects can be explicitly aligned
# ...

# %%
serie = pd.Series([11, 22, 33, 44])
serie
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64

# %%
serie.dtype
# Out:
# dtype('int64')

# %%
serie[serie > 22]
# Out:
# 2    33
# 3    44
# dtype: int64

# %%
serie = pd.Series([11, 22, 33, 44], dtype=pd.Int32Dtype)
serie
# Out:
# /var/folders/3k/f_77v9pn1r94_xmvm2w3xgqr0000gn/T/ipykernel_8550/3048422829.py:1: UserWarning: Instantiating Int32Dtype without any arguments.Pass a Int32Dtype instance to silence this warning.
#   serie = pd.Series([11, 22, 33, 44], dtype=pd.Int32Dtype)
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: Int32

# %%
serie1 = pd.Series([11, 22, 33, 44])
serie2 = pd.Series([88, 99, 111, 222])

# %%
arr = np.array([11, 22, 33, 44])
# Seria poate primi un np array
serie1 = pd.Series(arr)
serie1
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64

# %%
dictionar = {"inaltime":180, "greutate":80, "an":2026}

serie1 = pd.Series(dictionar)
serie1
# Out:
# inaltime     180
# greutate      80
# an          2026
# dtype: int64

# %%
arr = np.array([11, 22, 33, 44])
serie1 = pd.Series(arr)

serie2 = pd.Series([88, 99, 111, 222])

# %%
df = pd.DataFrame([serie1, serie2])
df
# Out:
#     0   1    2    3
# 0  11  22   33   44
# 1  88  99  111  222

# %%
df = pd.DataFrame({"coloana1": serie1, "coloana2": serie2})
df
# Out:
#    coloana1  coloana2
# 0        11        88
# 1        22        99
# 2        33       111
# 3        44       222

# %%
print(df)
# Out:
#    coloana1  coloana2
# 0        11        88
# 1        22        99
# 2        33       111
# 3        44       222

# %%
df.plot()
# Out:
# <Axes: >

# %%
df
# Out:
#    coloana1  coloana2
# 0        11        88
# 1        22        99
# 2        33       111
# 3        44       222

# %%
df[df["coloana1"] > 11]
# Out:
#    coloana1  coloana2
# 1        22        99
# 2        33       111
# 3        44       222

# %%
new_df = df[(df["coloana1"] > 11) & (df["coloana2"] < 200)]
new_df
# Out:
#    coloana1  coloana2
# 1        22        99
# 2        33       111

# %%
new_df
# Out:
#    coloana1  coloana2
# 1        22        99
# 2        33       111

# %%
df
# Out:
#    coloana1  coloana2
# 0        11        88
# 1        22        99
# 2        33       111
# 3        44       222

# %%
filtrare_dupa_coloana = df["coloana1"]
filtrare_dupa_coloana
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# Name: coloana1, dtype: int64

# %%
type(filtrare_dupa_coloana)
# Out:
# pandas.core.series.Series

# %%
df[["coloana1"]]
# Out:
#    coloana1
# 0        11
# 1        22
# 2        33
# 3        44

# %%
df[["coloana1", "coloana2"]]
# Out:
#    coloana1  coloana2
# 0        11        88
# 1        22        99
# 2        33       111
# 3        44       222

# %%
df.to_json("date.json")

# %%
df.to_csv("date.csv")

# %%
df.to_excel("date.xlsx")
