# %%
for i in range(6):
    x = int(input("Introduceti un numar"))
    print(x, "este par:",  x % 25 == 0)
# Out:
# 32 este par: True
# 11 este par: False
# 1215 este par: False
# 3 este par: False
# 2 este par: True
# 3 este par: False
