# %%
IF = 3210 # case-sensitive

# %%
if 10 > 2:
    print("Este mai mare...")
# Out:
# Este mai mare...

# %%
if 10 < 2:
    print("Este mai mare...")

# %%
if 10 < 2:
    print("Este mai mare...")
else:
    print("Nu este mai mare")
# Out:
# Nu este mai mare

# %%
x = 21

if x < 18:
    print("Mai mic decat 18")
else:
    print("Mai mare sau egal cu 18")
# Out:
# Mai mare sau egal cu 18

# %%
x = 18

if x < 18:
    print("Mai mic decat 18")
else:
    print("Mai mare sau egal cu 18")
# Out:
# Mai mare sau egal cu 18

# %%
x = 38

if x < 18:
    print("Mai mic decat 18")
else:
    print("Mai mare sau egal cu 18")
# Out:
# Mai mare sau egal cu 18

# %%
x = 38

if x < 18:
    print("Mai mic decat 18")
else:
    if x < 60:
        print("Mai mic decat 60")
    else:
        print("Mai mare sau egal de 60")
# Out:
# Mai mic decat 60

# %%
x = 38

if x < 18:
    print("Mai mic decat 18")
elif x < 60:
    print("Mai mic decat 60")
else:
    print("Mai mare sau egal de 60")
# Out:
# Mai mic decat 60

# %% [markdown]
# # Indentarea nu are o valoare fix, dar este preferabil sa existe 4 spatii (1 tab)

# %%
x = 38

if x < 18:
 print("Mai mic decat 18")
elif x < 60:
                             print("Mai mic decat 60")
else:
    print("Mai mare sau egal de 60")
# Out:
# Mai mic decat 60
