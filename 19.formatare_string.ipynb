# %%
print(10, 2, 3, 4, 5)
# Out:
# 10 2 3 4 5

# %%
print(10 +  2 + 3 +  4 + 5)
# Out:
# 24

# %%
print("10" +  "2" + "3" +  "4" + "5")
# Out:
# 102345

# %%
print(10 +  "ADADA" + 4 + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(10 +  "ADADA" + 4 + 5)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x = 10

text = f"Valoarea lui x este {x}"
print(text)
# Out:
# Valoarea lui x este 10

# %%
x = 10312312

text = f"Valoarea lui x este {x}"
print(text)
# Out:
# Valoarea lui x este 10312312

# %%
x = 10312312
y = 3123
text = f"Valoarea lui x este {x}, valoare lui y este. {y}"
print(text)
# Out:
# Valoarea lui x este 10312312, valoare lui y este. 3123
