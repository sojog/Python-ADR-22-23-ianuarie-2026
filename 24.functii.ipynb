# %%
raza = int(input("Valoarea razei: "))
arie_cerc = 3.1415 * raza**2
print(arie_cerc)
# Out:
# 51470.336

# %%
if 10 > 3:
    pass

# %%
def calcul_raza(raza):
    arie_cerc = 3.1415 * raza**2
    print(arie_cerc)

# %%
calcul_raza(10)
# Out:
# 314.15000000000003

# %%
calcul_raza(4)
# Out:
# 50.264

# %%
def calculeaza_pret_cu_tva(pret):
    pret_cu_tva = pret * 1.21
    return pret_cu_tva

# %%
calculeaza_pret_cu_tva(200)
# Out:
# 242.0

# %%
def calculeaza_pret_cu_tva(pret, tva):
    pret_cu_tva = pret * (1 + tva)
    return pret_cu_tva

# %%
calculeaza_pret_cu_tva(200, 0.19)
# Out:
# 238.0

# %%
def calculeaza_pret_cu_tva(pret, tva = 0.21):
    pret_cu_tva = pret * (1 + tva)
    return pret_cu_tva

# %%
calculeaza_pret_cu_tva(200, 0.19)
# Out:
# 238.0

# %%
calculeaza_pret_cu_tva(200)
# Out:
# 242.0

# %%
range(6)
# Out:
# range(0, 6)

# %%
range(0, 6, 1)
# Out:
# range(0, 6)
