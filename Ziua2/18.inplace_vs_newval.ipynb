# %%
o_lista = [23, 20, 10, 90, 50, 40]

# %%
# se genereaza o noua lista
sorted(o_lista)
# Out:
# [10, 20, 23, 40, 50, 90]

# %%
o_lista
# Out:
# [23, 20, 10, 90, 50, 40]

# %%
# sortare in place
o_lista.sort()

# %%
o_lista
# Out:
# [10, 20, 23, 40, 50, 90]
