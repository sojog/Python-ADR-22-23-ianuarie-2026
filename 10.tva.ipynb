# %%
pret_fara_tva = input("Introduceti pretul \n")  
pret_fara_tva
# Out:
# '100'

# %%
pret_fara_tva = int(pret_fara_tva)
pret_fara_tva
# Out:
# 100

# %%
pret_cu_tva = pret_fara_tva * 1.21
pret_cu_tva
# Out:
# 121.0

# %%
type(pret_fara_tva)
# Out:
# int
