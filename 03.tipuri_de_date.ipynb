# %%
print("Hello World")
# Out:
# Hello World

# %%
## BOOL (boolean)
x = True # sau "False"
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>

# %%
# INT (integer)
x = 22
print(x)
print(type(x))
# Out:
# 22
# <class 'int'>

# %%
# FLOAT (floating number)
x = 22.656
print(x)
print(type(x))
# Out:
# 22.656
# <class 'float'>

# %%
# STR (string)
x = "22.656"
print(x)
print(type(x))
# Out:
# 22.656
# <class 'str'>
